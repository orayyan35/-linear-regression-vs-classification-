# %% [markdown]
# ## linear regression  vs classification

# %% [markdown]
# # regression:
# We may have two inputs for a specific thing(the area of a house or the number of rooms) and we have a specific output (its price) and We give the algorithm inputs and outputs, and it creates a suitable equation, best fit curve, through which the output, house price, can be predicted by giving the algorithm the inputs (area, number of rooms and address).

# %% [markdown]
# # classification:
# We have inputs about certain elements (the student’s age, general grade, and language proficiency) and we have an output (whether he will be accepted into the college or not)
# and We give the algorithm inputs and outputs (the accepted is 1 and the rejected is 0) and it divides the accepted students into a part and the rejected students into a part so that when we give it the input to a new student, the algorithm predicts whether it will be accepted or not.

# %% [markdown]
# ![Screenshot%202023-10-16%20at%2017.04.07.png](attachment:Screenshot%202023-10-16%20at%2017.04.07.png)

# %% [markdown]
# ![Screenshot%202023-10-16%20at%2017.04.47.png](attachment:Screenshot%202023-10-16%20at%2017.04.47.png)

# %% [markdown]
# ![Screenshot%202023-10-16%20at%2018.10.35.png](attachment:Screenshot%202023-10-16%20at%2018.10.35.png)
